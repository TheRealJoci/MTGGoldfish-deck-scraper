# %%
# !pip install scrapy

# %%
import scrapy
import pandas

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/ZP/scraper

# %%
# !scrapy startproject mtggoldfish
# Out:
# New Scrapy project 'mtggoldfish', using template directory '/usr/local/lib/python3.7/dist-packages/scrapy/templates/project', created in:
#     /content/drive/MyDrive/Colab Notebooks/ZP/scraper/mtggoldfish
#
# You can start your first spider with:
#     cd mtggoldfish
#     scrapy genspider example example.com

# %%
# %cd mtggoldfish

# %%
# !scrapy crawl decks
# Out:
# 2022-01-25 01:40:47 [scrapy.utils.log] INFO: Scrapy 2.5.1 started (bot: mtggoldfish)
# 2022-01-25 01:40:47 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 21.7.0, Python 3.7.12 (default, Sep 10 2021, 00:21:48) - [GCC 7.5.0], pyOpenSSL 21.0.0 (OpenSSL 1.1.1m  14 Dec 2021), cryptography 36.0.1, Platform Linux-5.4.144+-x86_64-with-Ubuntu-18.04-bionic
# 2022-01-25 01:40:47 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2022-01-25 01:40:47 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'mtggoldfish',
#  'NEWSPIDER_MODULE': 'mtggoldfish.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['mtggoldfish.spiders']}
# 2022-01-25 01:40:47 [scrapy.extensions.telnet] INFO: Telnet Password: e2df1846619f402a
# 2022-01-25 01:40:47 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
# ...
